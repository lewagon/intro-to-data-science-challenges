# %% [markdown]
# # Setup 💻

# %% [markdown]
# ### A. Importing libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### B. Loading Airbnb dataframe

# %%
listings_df = pd.read_csv('https://storage.googleapis.com/introduction-to-data-science/airbnb-dataset.csv')

# %% [markdown]
# --------

# %% [markdown]
# # Your Turn 💪

# %% [markdown]
# ## A. Manipulating dataframe

# %% [markdown]
# ### 1. Can you have a quick look at this dataframe displaying the first 5 rows?

# %%
# Your code goes here 💪

# %%
listings_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### 2. How many rows and columns are in the dataframe?

# %%
# Your code goes here 💪

# %%
listings_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### 3. What are the features (columns) of the dataframe?

# %%
# Your code goes here 💪

# %%
listings_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### 4. What are the types of data inside this dataframe?

# %%
# Your code goes here 💪

# %%
listings_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# Let's now clean the dataframe 👌

# %% [markdown]
# ### 5. Are they missing values?

# %%
# Your code goes here 💪

# %%
listings_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Let's say we do not want to manipulate data about `host_name`, and `last_reviews` and drop the column `id` as well.

# %% [markdown]
# ### 6. Can you drop the columns `id`, `host_name`, `last_review`?

# %%
columns_to_drop = ['id', 'host_name', 'last_review']
listings_df.drop(columns_to_drop, axis="columns", inplace=True)

# %%
# Let's see the results by printing the first rows of the dataframe 👇
listings_df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0                NaN
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# We can see that there are aa lots of `NaN`for the column `reviews_per_month`

# %% [markdown]
# ### 7. Can you replace `NaN` for `reviews_per_month` by `0`?

# %%
listings_df.fillna({'reviews_per_month': 0}, inplace=True)

# %%
# Let's see the result 👇
listings_df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0               0.00
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# ### 8. Can you have a look of this dataframe only throught the columns `name`, `neighbourhood_group`, `price`?

# %%
# Your code goes here 💪

# %%
listings_df[['name', 'neighbourhood_group', 'price']]
# Out:
#                                                     name neighbourhood_group  \
# 0                     Clean & quiet apt home by the park            Brooklyn
# 1                                  Skylit Midtown Castle           Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                        Cozy Entire Floor of Brownstone            Brooklyn
# 4       Entire Apt: Spacious Studio/Loft by central park           Manhattan
# 5              Large Cozy 1 BR Apartment In Midtown East           Manhattan
# 6                                        BlissArtsSpace!            Brooklyn
# 7                       Large Furnished Room Near B'way            Manhattan
# 8                     Cozy Clean Guest Room - Family Apt           Manhattan
# 9                     Cute & Cozy Lower East Side 1 bdrm           Manhattan
# 10                      Beautiful 1br on Upper West Side           Manhattan
# 11                       Central Manhattan/near Broadway           Manhattan
# 12        Lovely Room 1, Garden, Best Area, Legal rental            Brooklyn
# 13      Wonderful Guest Bedroom in Manhattan for SINGLES           Manhattan
# 14                         West Village Nest - Superhost           Manhattan
# 15                      Only 2 stops to Manhattan studio            Brooklyn
# 16                     Perfect for Your Parents + Garden            Brooklyn
# 17                                       Chelsea Perfect           Manhattan
# 18       Hip Historic Brownstone Apartment with Backyard            Brooklyn
# 19                     Huge 2 BR Upper East  Cental Park           Manhattan
# 20                      Sweet and Spacious Brooklyn Loft            Brooklyn
# 21                        CBG CtyBGd HelpsHaiti rm#1:1-4            Brooklyn
# 22                              CBG Helps Haiti Room#2.5            Brooklyn
# 23                                 CBG Helps Haiti Rm #2            Brooklyn
# 24                MAISON DES SIRENES1,bohemian apartment            Brooklyn
# 25                    Sunny Bedroom Across Prospect Park            Brooklyn
# 26     Magnifique Suite au N de Manhattan - vue Cloitres           Manhattan
# 27                                  Midtown Pied-a-terre           Manhattan
# 28          SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM           Manhattan
# 29                      Modern 1 BR / NYC / EAST VILLAGE           Manhattan
# ...                                                  ...                 ...
# 48865                      1 bedroom in sunlit apartment           Manhattan
# 48866                                 CozyHideAway Suite              Queens
# 48867    The place you were dreaming for.(only for guys)            Brooklyn
# 48868                       Heaven for you(only for guy)            Brooklyn
# 48869                        Cozy, Sunny Brooklyn Escape            Brooklyn
# 48870      Cozy, clean Williamsburg 1- bedroom apartment            Brooklyn
# 48871      A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER           Manhattan
# 48872                                      Nycity-MyHome           Manhattan
# 48873                                  Brooklyn paradise            Brooklyn
# 48874                   Short Term Rental in East Harlem           Manhattan
# 48875                              Welcome all as family           Manhattan
# 48876    Cozy, Air-Conditioned Private Bedroom in Harlem           Manhattan
# 48877             Studio sized room with beautiful light            Brooklyn
# 48878                                      Room for rest              Queens
# 48879  Gorgeous 1.5 Bdr with a private yard- Williams...            Brooklyn
# 48880  The Raccoon Artist Studio in Williamsburg New ...            Brooklyn
# 48881                   Peaceful space in Greenpoint, BK            Brooklyn
# 48882                          Bushwick _ Myrtle-Wyckoff            Brooklyn
# 48883       Sunny Bedroom NYC! Walking to Central Park!!           Manhattan
# 48884        Brooklyn Oasis in the heart of Williamsburg            Brooklyn
# 48885    Stunning Bedroom NYC! Walking to Central Park!!           Manhattan
# 48886                    Comfy 1 Bedroom in Midtown East           Manhattan
# 48887    Garden Jewel Apartment in Williamsburg New York            Brooklyn
# 48888  Spacious Room w/ Private Rooftop, Central loca...           Manhattan
# 48889                                 QUIT PRIVATE HOUSE              Queens
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#        price
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
# 5        200
# 6         60
# 7         79
# 8         79
# 9        150
# 10       135
# 11        85
# 12        89
# 13        85
# 14       120
# 15       140
# 16       215
# 17       140
# 18        99
# 19       190
# 20       299
# 21       130
# 22        80
# 23       110
# 24       120
# 25        60
# 26        80
# 27       150
# 28        44
# 29       180
# ...      ...
# 48865     80
# 48866     58
# 48867     25
# 48868     25
# 48869     45
# 48870     99
# 48871     35
# 48872    260
# 48873    170
# 48874     50
# 48875    140
# 48876     60
# 48877     42
# 48878     45
# 48879    120
# 48880    120
# 48881     54
# 48882     40
# 48883     75
# 48884    190
# 48885     75
# 48886    200
# 48887    170
# 48888    125
# 48889     65
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
#
# [48895 rows x 3 columns]

# %% [markdown]
# ###  9. Can you display the first 9 rows of the daset?

# %%
# Your code goes here 💪

# %%
listings_df[0:8]
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
# 5         Large Cozy 1 BR Apartment In Midtown East     7322
# 6                                   BlissArtsSpace!     7356
# 7                  Large Furnished Room Near B'way      8967
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn          Kensington  40.64749  -73.97237
# 1           Manhattan             Midtown  40.75362  -73.98377
# 2           Manhattan              Harlem  40.80902  -73.94190
# 3            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4           Manhattan         East Harlem  40.79851  -73.94399
# 5           Manhattan         Murray Hill  40.74767  -73.97500
# 6            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
# 5  Entire home/apt    200               3                 74
# 6     Private room     60              45                 49
# 7     Private room     79               2                430
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
# 6               0.40                               1                 0
# 7               3.47                               1               220

# %% [markdown]
# ### 10. Can you display the first 9 columns of this dataframe indexed by `name`, `neighbourhood_group`, `price`?

# %%
# Your code goes here 💪

# %%
listings_df[0:8][['name', 'neighbourhood_group', 'price']]
# Out:
#                                                name neighbourhood_group  price
# 0                Clean & quiet apt home by the park            Brooklyn    149
# 1                             Skylit Midtown Castle           Manhattan    225
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan    150
# 3                   Cozy Entire Floor of Brownstone            Brooklyn     89
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan     80
# 5         Large Cozy 1 BR Apartment In Midtown East           Manhattan    200
# 6                                   BlissArtsSpace!            Brooklyn     60
# 7                  Large Furnished Room Near B'way            Manhattan     79

# %% [markdown]
# ### 11. Let's print the flats which have a price below `100`?

# %%
# Your code goes here 💪

# %%
listings_df[listings_df['price'] < 100]
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# 11                       Central Manhattan/near Broadway       7989
# 12        Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13      Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18       Hip Historic Brownstone Apartment with Backyard      20950
# 22                              CBG Helps Haiti Room#2.5      22486
# 25                    Sunny Bedroom Across Prospect Park      25326
# 26     Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 28          SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM      31374
# 30                                 front room/double bed      32294
# 31                   Spacious 1 bedroom in luxe building      32045
# 32                     Loft in Williamsburg Area w/ Roof      32169
# 33                                   back room/bunk beds      32294
# 34                                 Large B&B Style rooms      35935
# 35       Lovely room 2 & garden; Best area, Legal rental       9744
# 36                           Clean and Quiet in Brooklyn       7355
# 37                             Cute apt in artist's home      44145
# 39                   LowerEastSide apt share shortterm 1       7549
# 40                                   ENJOY Downtown NYC!      46978
# 49                               Fort Greene brownstone       52335
# 50       Blue Room for 2 in Brownstone for $1350 monthly      54275
# 57                   Best Location in NYC! TIMES SQUARE!      59734
# 58                       Room in Greenpoint Loft w/ Roof      32169
# 60                                 Very, very cozy place      60252
# 64     Double Room w Private Deck Clinton Hill Best Area      63613
# 65                          Your Heaven in Hells Kitchen      63924
# ...                                                  ...        ...
# 48847  #6 New Hotel-Like Private Room QUEEN Bed near JFK  263504959
# 48849                          Studio in Manhattan(独立出入)  257261595
# 48851   #7 New Hotel-Like Private Room KING bed near JFK  263504959
# 48852            Cozy Private Room in Bushwick, Brooklyn   74162901
# 48855                  Perfectly Located Organic Getaway    6677425
# 48857      ❥NYC Apt: 4min/subway, 25m/city, 20m/LGA,JFK❥   63272360
# 48858  2beds Private Room Step to LGA, CitiFiled, Mid...  217463199
# 48859       two girls room , I speak Chinese and English  274188386
# 48863                Comfortable & Big room with 2 beds!  274012871
# 48864    Private Bedroom & PRIVATE BATHROOM in Manhattan   23548340
# 48865                      1 bedroom in sunlit apartment   99144947
# 48866                                 CozyHideAway Suite  274225617
# 48867    The place you were dreaming for.(only for guys)  261338177
# 48868                       Heaven for you(only for guy)  261338177
# 48869                        Cozy, Sunny Brooklyn Escape    1550580
# 48870      Cozy, clean Williamsburg 1- bedroom apartment    1273444
# 48871      A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
# 48874                   Short Term Rental in East Harlem  214535893
# 48876    Cozy, Air-Conditioned Private Bedroom in Harlem  177932088
# 48877             Studio sized room with beautiful light   65767720
# 48878                                      Room for rest   41326856
# 48881                   Peaceful space in Greenpoint, BK  274298453
# 48882                          Bushwick _ Myrtle-Wyckoff   66058896
# 48883       Sunny Bedroom NYC! Walking to Central Park!!  131529729
# 48885    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48889                                 QUIT PRIVATE HOUSE  107716952
# 48890    Charming one bedroom - newly renovated rowhouse    8232441
# 48891      Affordable room in Bushwick/East Williamsburg    6570630
# 48893               43rd St. Time Square-cozy single bed   30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# 6                Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7               Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8               Manhattan     Upper West Side  40.80178  -73.96723
# 11              Manhattan      Hell's Kitchen  40.76076  -73.98867
# 12               Brooklyn         South Slope  40.66829  -73.98779
# 13              Manhattan     Upper West Side  40.79826  -73.96113
# 18               Brooklyn       Crown Heights  40.67592  -73.94694
# 22               Brooklyn          Park Slope  40.67989  -73.97798
# 25               Brooklyn     Windsor Terrace  40.65599  -73.97519
# 26              Manhattan              Inwood  40.86754  -73.92639
# 28              Manhattan              Inwood  40.86482  -73.92106
# 30              Manhattan              Harlem  40.82245  -73.95104
# 31              Manhattan              Harlem  40.81305  -73.95466
# 32               Brooklyn          Greenpoint  40.72219  -73.93762
# 33              Manhattan              Harlem  40.82130  -73.95318
# 34               Brooklyn  Bedford-Stuyvesant  40.68310  -73.95473
# 35               Brooklyn         South Slope  40.66869  -73.98780
# 36               Brooklyn  Bedford-Stuyvesant  40.68876  -73.94312
# 37               Brooklyn            Bushwick  40.70186  -73.92745
# 39              Manhattan     Lower East Side  40.71401  -73.98917
# 40              Manhattan        East Village  40.72290  -73.98199
# 49               Brooklyn         Fort Greene  40.69142  -73.97376
# 50               Brooklyn  Bedford-Stuyvesant  40.68043  -73.93934
# 57              Manhattan      Hell's Kitchen  40.75531  -73.99293
# 58               Brooklyn          Greenpoint  40.72401  -73.93788
# 60               Brooklyn        Williamsburg  40.71185  -73.96204
# 64               Brooklyn        Clinton Hill  40.69000  -73.96788
# 65              Manhattan      Hell's Kitchen  40.75979  -73.99119
# ...                   ...                 ...       ...        ...
# 48847              Queens           Woodhaven  40.69183  -73.86523
# 48849           Manhattan              Harlem  40.80951  -73.95347
# 48851              Queens           Woodhaven  40.69137  -73.86591
# 48852            Brooklyn            Bushwick  40.69805  -73.92801
# 48855           Manhattan     Upper West Side  40.79753  -73.96155
# 48857              Queens           Woodhaven  40.69482  -73.86618
# 48858              Queens            Flushing  40.74387  -73.82556
# 48859           Manhattan        East Village  40.73197  -73.98674
# 48863              Queens    Long Island City  40.76726  -73.93936
# 48864           Manhattan     Upper East Side  40.77192  -73.95369
# 48865           Manhattan              Inwood  40.86845  -73.92449
# 48866              Queens           Briarwood  40.70786  -73.81448
# 48867            Brooklyn           Gravesend  40.59080  -73.97116
# 48868            Brooklyn           Gravesend  40.59118  -73.97119
# 48869            Brooklyn  Bedford-Stuyvesant  40.68759  -73.95705
# 48870            Brooklyn        Williamsburg  40.71197  -73.94946
# 48871           Manhattan              Harlem  40.82233  -73.94687
# 48874           Manhattan         East Harlem  40.79760  -73.93947
# 48876           Manhattan              Harlem  40.80953  -73.95410
# 48877            Brooklyn            Bushwick  40.70418  -73.91471
# 48878              Queens            Elmhurst  40.74477  -73.87727
# 48881            Brooklyn          Greenpoint  40.72585  -73.94001
# 48882            Brooklyn            Bushwick  40.69652  -73.91079
# 48883           Manhattan         East Harlem  40.79755  -73.93614
# 48885           Manhattan         East Harlem  40.79633  -73.93605
# 48889              Queens             Jamaica  40.69137  -73.80844
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 3      Entire home/apt     89               1                270
# 4      Entire home/apt     80              10                  9
# 6         Private room     60              45                 49
# 7         Private room     79               2                430
# 8         Private room     79               2                118
# 11        Private room     85               2                188
# 12        Private room     89               4                167
# 13        Private room     85               2                113
# 18     Entire home/apt     99               3                 53
# 22        Private room     80               1                 39
# 25        Private room     60               1                 19
# 26        Private room     80               4                  0
# 28        Private room     44               3                108
# 30        Private room     50               3                242
# 31        Private room     52               2                 88
# 32        Private room     55               4                197
# 33        Private room     50               3                273
# 34        Private room     70               1                 74
# 35        Private room     89               4                168
# 36        Private room     35              60                  0
# 37     Entire home/apt     85               2                231
# 39         Shared room     40               1                214
# 40        Private room     68               2                245
# 49        Private room     80               3                135
# 50        Private room     80               1                112
# 57        Private room     69               2                289
# 58        Private room     49               4                138
# 60        Private room     80               2                 42
# 64        Private room     55               7                 27
# 65        Private room     52              30                191
# ...                ...    ...             ...                ...
# 48847     Private room     34               1                  0
# 48849  Entire home/apt     65               1                  0
# 48851     Private room     35               1                  0
# 48852     Private room     30               1                  1
# 48855      Shared room     55               2                  0
# 48857  Entire home/apt     85               3                  0
# 48858     Private room     68               3                  0
# 48859     Private room     93               7                  0
# 48863     Private room     93               2                  0
# 48864     Private room     95               1                  0
# 48865     Private room     80               1                  0
# 48866  Entire home/apt     58               1                  0
# 48867      Shared room     25               1                  0
# 48868      Shared room     25               7                  0
# 48869     Private room     45               4                  0
# 48870  Entire home/apt     99               4                  0
# 48871     Private room     35              29                  0
# 48874     Private room     50               7                  0
# 48876     Private room     60               1                  0
# 48877     Private room     42               7                  0
# 48878     Private room     45               1                  0
# 48881     Private room     54               6                  0
# 48882     Private room     40              20                  0
# 48883     Private room     75               2                  0
# 48885     Private room     75               2                  0
# 48889     Private room     65               1                  0
# 48890     Private room     70               2                  0
# 48891     Private room     40               4                  0
# 48893      Shared room     55               1                  0
# 48894     Private room     90               7                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 6                   0.40                               1                 0
# 7                   3.47                               1               220
# 8                   0.99                               1                 0
# 11                  1.50                               1                39
# 12                  1.34                               3               314
# 13                  0.91                               1               333
# 18                  4.44                               1                21
# 22                  0.37                               6               364
# 25                  1.37                               2                85
# 26                  0.00                               1                 0
# 28                  1.11                               3               311
# 30                  2.04                               3               355
# 31                  1.42                               1               255
# 32                  1.65                               3               284
# 33                  2.37                               3               359
# 34                  0.66                               2               269
# 35                  1.41                               3               340
# 36                  0.00                               1               365
# 37                  1.96                               2                22
# 39                  1.81                               4               188
# 40                  2.08                               2                96
# 49                  1.16                               2               192
# 50                  1.01                               3               251
# 57                  2.49                               2               294
# 58                  1.19                               3               320
# 60                  0.38                               1               263
# 64                  0.23                               2               292
# 65                  1.65                               1               191
# ...                  ...                             ...               ...
# 48847               0.00                               8               320
# 48849               0.00                               1                32
# 48851               0.00                               8               341
# 48852               1.00                               1                 1
# 48855               0.00                               2                49
# 48857               0.00                               6               300
# 48858               0.00                               4               362
# 48859               0.00                               1               173
# 48863               0.00                               2                14
# 48864               0.00                               1                 2
# 48865               0.00                               1                79
# 48866               0.00                               1               159
# 48867               0.00                               6               338
# 48868               0.00                               6               365
# 48869               0.00                               1                 7
# 48870               0.00                               1                22
# 48871               0.00                               2                31
# 48874               0.00                               1                22
# 48876               0.00                               1                26
# 48877               0.00                               1                16
# 48878               0.00                               5               172
# 48881               0.00                               1                15
# 48882               0.00                               1                31
# 48883               0.00                               2               364
# 48885               0.00                               2               353
# 48889               0.00                               2               163
# 48890               0.00                               2                 9
# 48891               0.00                               2                36
# 48893               0.00                               6                 2
# 48894               0.00                               1                23
#
# [21877 rows x 13 columns]

# %% [markdown]
# ## B. Exploratory Data analysis

# %% [markdown]
# ### 1. What are the 10 most reviewed listings?

# %%
# Your code goes here 💪

# %%
listings_df.nlargest(10, 'number_of_reviews')
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 4870                  Private brownstone studio Brooklyn  12949460
# 471                      LG Private Room/Family Friendly    792159
#
#       neighbourhood_group    neighbourhood  latitude  longitude  \
# 11759              Queens          Jamaica  40.66730  -73.76831
# 2031            Manhattan           Harlem  40.82085  -73.94025
# 2030            Manhattan           Harlem  40.82124  -73.93838
# 2015            Manhattan           Harlem  40.82264  -73.94041
# 13495              Queens          Jamaica  40.66939  -73.76975
# 10623              Queens    East Elmhurst  40.77006  -73.87683
# 1879            Manhattan  Lower East Side  40.71921  -73.99116
# 20403              Queens    East Elmhurst  40.76335  -73.87007
# 4870             Brooklyn       Park Slope  40.67926  -73.97711
# 471              Brooklyn         Bushwick  40.70283  -73.92131
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 11759     Private room     47               1                629
# 2031      Private room     49               1                607
# 2030      Private room     49               1                597
# 2015      Private room     49               1                594
# 13495     Private room     47               1                576
# 10623     Private room     46               1                543
# 1879      Private room     99               2                540
# 20403     Private room     48               1                510
# 4870   Entire home/apt    160               1                488
# 471       Private room     60               3                480
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 11759              14.58                               2               333
# 2031                7.75                               3               293
# 2030                7.72                               3               342
# 2015                7.57                               3               339
# 13495              13.40                               2               173
# 10623              11.59                               5               163
# 1879                6.95                               1               179
# 20403              16.22                               5               341
# 4870                8.14                               1               269
# 471                 6.70                               1                 0

# %% [markdown]
# ### 2. What are the different neighourhoods in NYC?

# %%
# Your code goes here 💪

# %%
listings_df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
#        'Greenwich Village', 'Little Italy', 'East Flatbush',
#        'Tompkinsville', 'Astoria', 'Clason Point', 'Eastchester',
#        'Kingsbridge', 'Two Bridges', 'Queens Village', 'Rockaway Beach',
#        'Forest Hills', 'Nolita', 'Woodlawn', 'University Heights',
#        'Gravesend', 'Gramercy', 'Allerton', 'East New York',
#        'Theater District', 'Concourse Village', 'Sheepshead Bay',
#        'Emerson Hill', 'Fort Hamilton', 'Bensonhurst', 'Tribeca',
#        'Shore Acres', 'Sunset Park', 'Concourse', 'Elmhurst',
#        'Brighton Beach', 'Jackson Heights', 'Cypress Hills', 'St. Albans',
#        'Arrochar', 'Rego Park', 'Wakefield', 'Clifton', 'Bay Ridge',
#        'Graniteville', 'Spuyten Duyvil', 'Stapleton', 'Briarwood',
#        'Ozone Park', 'Columbia St', 'Vinegar Hill', 'Mott Haven',
#        'Longwood', 'Canarsie', 'Battery Park City', 'Civic Center',
#        'East Elmhurst', 'New Springville', 'Morris Heights', 'Arverne',
#        'Cambria Heights', 'Tottenville', 'Mariners Harbor', 'Concord',
#        'Borough Park', 'Bayside', 'Downtown Brooklyn', 'Port Morris',
#        'Fieldston', 'Kew Gardens', 'Midwood', 'College Point',
#        'Mount Eden', 'City Island', 'Glendale', 'Port Richmond',
#        'Red Hook', 'Richmond Hill', 'Bellerose', 'Maspeth',
#        'Williamsbridge', 'Soundview', 'Woodhaven', 'Woodrow',
#        'Co-op City', 'Stuyvesant Town', 'Parkchester', 'North Riverdale',
#        'Dyker Heights', 'Bronxdale', 'Sea Gate', 'Riverdale',
#        'Kew Gardens Hills', 'Bay Terrace', 'Norwood', 'Claremont Village',
#        'Whitestone', 'Fordham', 'Bayswater', 'Navy Yard', 'Brownsville',
#        'Eltingville', 'Fresh Meadows', 'Mount Hope', 'Lighthouse Hill',
#        'Springfield Gardens', 'Howard Beach', 'Belle Harbor',
#        'Jamaica Estates', 'Van Nest', 'Morris Park', 'West Brighton',
#        'Far Rockaway', 'South Ozone Park', 'Tremont', 'Corona',
#        'Great Kills', 'Manhattan Beach', 'Marble Hill', 'Dongan Hills',
#        'Castleton Corners', 'East Morrisania', 'Hunts Point', 'Neponsit',
#        'Pelham Bay', 'Randall Manor', 'Throgs Neck', 'Todt Hill',
#        'West Farms', 'Silver Lake', 'Morrisania', 'Laurelton',
#        'Grymes Hill', 'Holliswood', 'Pelham Gardens', 'Belmont',
#        'Rosedale', 'Edgemere', 'New Brighton', 'Midland Beach',
#        'Baychester', 'Melrose', 'Bergen Beach', 'Richmondtown',
#        'Howland Hook', 'Schuylerville', 'Coney Island', 'New Dorp Beach',
#        "Prince's Bay", 'South Beach', 'Bath Beach', 'Jamaica Hills',
#        'Oakwood', 'Castle Hill', 'Hollis', 'Douglaston', 'Huguenot',
#        'Olinville', 'Edenwald', 'Grant City', 'Westerleigh',
#        'Bay Terrace, Staten Island', 'Westchester Square', 'Little Neck',
#        'Fort Wadsworth', 'Rosebank', 'Unionport', 'Mill Basin',
#        'Arden Heights', "Bull's Head", 'New Dorp', 'Rossville',
#        'Breezy Point', 'Willowbrook'], dtype=object)

# %% [markdown]
# ### 3. What are the different neighourhood group in NYC?

# %%
# Your code goes here 💪

# %%
listings_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ### 4. [Follow-up] Can you count how many flats are per neighbourhood group?

# %%
# Your code goes here 💪

# %%
listings_df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# ### 5.  What are the Top 10 neighbourhoods?

# %%
# Your code goes here 💪

# %%
listings_df['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %% [markdown]
# ### 6. Can you plot the repartion of the Top 10 neighbourhoods on an histogram?

# %%
# Your code goes here 💪

# %%
listings_df['neighbourhood'].value_counts().head(10).plot(kind='bar')

# %%
# Well let's use the sns library to have a better nice charts!
sns.countplot(data=listings_df, x='neighbourhood_group')

# %% [markdown]
# ### 7. What's the different room types?

# %%
# Your code goes here 💪

# %%
listings_df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %% [markdown]
# ### 8. Can you plot the repartition of types of rooms per neighbourhood group?

# %%
# Your code goes here 💪

# %%
sns.countplot(data=listings_df, x='neighbourhood_group', hue='room_type')

# %% [markdown]
# ### 9. What is the distribution of flat prices?

# %%
# Your code goes here 💪

# %%
sns.distplot(listings_df['price'])

# %% [markdown]
# ### 10. Can you plot the distribution of the flats which have a price below `500`?

# %%
# Your code goes here 💪

# %%
affordable_df = listings_df[listings_df['price'] <= 500]
sns.distplot(affordable_df['price'])

# %% [markdown]
# ### 11. What is the average price of a flat?

# %%
# Your code goes here 💪

# %%
affordable_df['price'].mean()
# Out:
# 131.53056362458466

# %% [markdown]
# ### 12.  What is the distribution of flat prices based on the Neighbourhood Group?

# %%
# Your code goes here 💪

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(15, 8))
sns.violinplot(data=affordable_df, x="neighbourhood_group", y="price")

# %% [markdown]
# ### 13. Can we plot the listings on a map?

# %%
affordable_df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0               0.00
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
affordable_df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))

# %%
import urllib
i = urllib.request.urlopen('https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG')
plt.imshow(plt.imread(i), zorder=0, extent=[-74.258, -73.7, 40.49, 40.92])
ax = plt.gca()
affordable_df.plot(
    ax=ax,
    zorder=1,
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))
